# %%
import os
import pandas as pd
import janitor
import numpy as np
pd.set_option('display.max_columns', 100)

from utils.data_utils import fit_quantile_reg, fit_ols_reg, esttab_ols_quantile
from utils.utils import save_mpl_fig
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(context="notebook", font_scale=1.05, style="whitegrid", palette="dark")
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

FIGSAVEDIR = "../figs"
DATAPATH = "../data/individual_browsing_data_piedomains.csv"        

df_ind = (pd.read_csv(DATAPATH)
          # Normalize seconds to hours
          .assign(
              duration_adult=lambda df: df.duration_adult/3600,
              duration_nonadult=lambda df: df.duration_nonadult/3600,
          )
         )
df_ind
# Out:
#          caseid  birthyr  gender  race  educ  pid3  pid7  presvote20post  \
# 0     200661421     1963       2     1     4     3     3               1
# 1     200686597     1992       2     6     5     5     8              -1
# 2     200953869     1959       2     1     5     2     7               2
# 3     201302005     1966       2     2     3     5     8               1
# 4     201590505     1977       1     4     5     3     3               1
# ...         ...      ...     ...   ...   ...   ...   ...             ...
# 1195    1802885     1935       1     1     6     4     5               2
# 1196    1809723     1943       1     1     2     1     1               1
# 1197    1827351     1947       1     1     5     3     4               1
# 1198    1924249     1980       1     7     4     2     7               2
# 1199    1988109     1953       2     3     5     3     4               6
#
#       inputstate  region party  visits_adult  visits_nonadult   visits  \
# 0             39       2     D           0.0           1728.0   1728.0
# 1             48       3   NaN         178.0           4059.0   4237.0
# 2             42       1     R           0.0             20.0     20.0
# 3             12       3   NaN          20.0            527.0    547.0
# 4              6       4     D           0.0          11086.0  11086.0
# ...          ...     ...   ...           ...              ...      ...
# 1195          12       3     R           NaN              NaN      NaN
# 1196          51       3     D           0.0           9805.0   9805.0
# 1197          31       2     I           0.0            543.0    543.0
# 1198           6       4     R          28.0          21533.0  21561.0
# 1199          51       3     I           0.0           7158.0   7158.0
#
#       prop_adult_visits  rep  duration_adult  duration_nonadult   duration  \
# 0              0.000000  0.0        0.000000          21.567222    77642.0
# 1              4.201086  NaN        5.727778          66.535556   260148.0
# 2              0.000000  1.0        0.000000           0.328333     1182.0
# 3              3.656307  NaN        1.712778           6.626389    30021.0
# 4              0.000000  0.0        0.000000         106.433611   383161.0
# ...                 ...  ...             ...                ...        ...
# 1195                NaN  1.0             NaN                NaN        NaN
# 1196           0.000000  0.0        0.000000         353.503611  1272613.0
# 1197           0.000000  NaN        0.000000           6.646944    23929.0
# 1198           0.129864  1.0        0.171111          86.487222   311970.0
# 1199           0.000000  NaN        0.000000          59.665833   214797.0
#
#       prop_adult_duration  yes_visit_adults  race2  cohort  age  age2  educ2
# 0                0.000000               0.0      1    1960   60  3600      4
# 1                7.926257               1.0      5    1990   31   961      4
# 2                0.000000               0.0      1    1960   64  4096      4
# 3               20.538956               1.0      2    1970   57  3249      3
# 4                0.000000               0.0      4    1980   46  2116      4
# ...                   ...               ...    ...     ...  ...   ...    ...
# 1195                  NaN               NaN      1    1940   88  7744      4
# 1196             0.000000               0.0      1    1940   80  6400      2
# 1197             0.000000               0.0      1    1950   76  5776      4
# 1198             0.197455               1.0      5    1980   43  1849      4
# 1199             0.000000               0.0      3    1950   70  4900      4
#
# [1200 rows x 26 columns]

# %%
quantiles = np.arange(0.05, 1, 0.05)
quantiles
# Out:
# array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])

# %%
# (fold cell) Standard graph opts
opts_connected_line = {
    "linewidth":2,
    "markersize":7,
    "markerfacecolor":"0",
    "markeredgecolor":"0",
    "color":".4",
}
opts_fillbetween = {
    "color":".7",
    "zorder":1,
    "alpha":.8,
}
opts_0yline = {
    "color":"maroon",
    "alpha":.6,
    "linewidth":2,
    "zorder":1,
}

# %% [markdown]
# ### Duration on adult

# %%
outcome = "duration_adult"
savepath = "piedomains_quantile_reg_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep",  quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)

# Custom Legend
quantile_estimates = mlines.Line2D([], [], 
                                   marker='o', ls="--",
                                   **opts_connected_line,
                                   label='Quantile estimates (connected)',
                                  )
ci = mpatches.Patch(**opts_fillbetween, label='95% confidence interval')
yline0 = mlines.Line2D([], [], 
                       **opts_0yline,
                       label="Estimate = 0"
                      )
custom_legend = plt.legend(
    handles=[quantile_estimates, ci, yline0], 
    handlelength=4, 
    handletextpad=.3,
    labelspacing=.3,
    frameon=False,
    prop={'weight':'bold', "size":14},
    loc="best",
#     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Hours spent on\nonline pornography sites", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: duration_adult</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.26<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup>***</sup></td><td>0.01<sup></sup></td><td>0.06<sup></sup></td><td>0.38<sup></sup></td><td>0.48<sup></sup></td><td>0.83<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.26)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.02)</td><td>(0.06)</td><td>(0.23)</td><td>(0.70)</td><td>(0.90)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>0.69<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup>***</sup></td><td>0.04<sup>**</sup></td><td>0.11<sup>***</sup></td><td>0.40<sup>***</sup></td><td>1.07<sup>**</sup></td><td>4.19<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.14)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.02)</td><td>(0.04)</td><td>(0.15)</td><td>(0.44)</td><td>(0.56)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>3.46 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.56 (df=832)</td><td>3.55 (df=832)</td><td>3.55 (df=832)</td><td>3.53 (df=832)</td><td>3.47 (df=832)</td><td>3.50 (df=832)</td><td>5.10 (df=832)</td></tr><tr><td style="text-align: left">F Statistic</td><td>1.02<sup></sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ### Proportion duration on adult

# %%
outcome = "prop_adult_duration"
savepath = "piedomains_quantile_reg_proportion_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)

# Custom Legend
quantile_estimates = mlines.Line2D([], [], 
                                   marker='o', ls="--",
                                   **opts_connected_line,
                                   label='Quantile estimates (connected)',
                                  )
ci = mpatches.Patch(**opts_fillbetween, label='95% confidence interval')
yline0 = mlines.Line2D([], [], 
                       **opts_0yline,
                       label="Estimate = 0"
                      )
custom_legend = plt.legend(
    handles=[quantile_estimates, ci, yline0], 
    handlelength=4, 
    handletextpad=.3,
    labelspacing=.3,
    frameon=False,
    prop={'weight':'bold', "size":14},
    loc="best",
#     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage of time spent on\nonline pornography sites (%)", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: prop_adult_duration</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.60<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup>***</sup></td><td>0.02<sup></sup></td><td>0.16<sup></sup></td><td>1.10<sup>*</sup></td><td>1.48<sup></sup></td><td>3.34<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.66)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.07)</td><td>(0.24)</td><td>(0.63)</td><td>(1.66)</td><td>(3.69)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>2.13<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.02<sup>***</sup></td><td>0.08<sup>*</sup></td><td>0.31<sup>**</sup></td><td>1.16<sup>***</sup></td><td>3.65<sup>***</sup></td><td>10.85<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.37)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.04)</td><td>(0.15)</td><td>(0.40)</td><td>(1.05)</td><td>(2.32)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td><td>834</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>8.93 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.25 (df=832)</td><td>9.23 (df=832)</td><td>9.16 (df=832)</td><td>8.97 (df=832)</td><td>9.14 (df=832)</td><td>13.35 (df=832)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.83<sup></sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td><td>nan<sup>***</sup> (df=1; 832)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
