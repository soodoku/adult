# %%
import os
import pandas as pd
import janitor
import numpy as np

pd.set_option("display.max_columns", 100)

from utils.utils import save_mpl_fig
from utils.data_utils import lowess_ci
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(context="notebook", font_scale=1.5, style="whitegrid")

FIGSAVEDIR = "../figs"
DATAPATH = "../adult-data"

# %%
# (fold cell) Load and prep web browsing data
# output = df with visits to adult sites
usecols_web_desktop = [
    "caseid",
    "category",
    "private_domain",
    "visit_duration",
    "visit_time_local",
]
usecols = [
    "caseid",
    "category",
    "private_domain",
    "page_duration",
    "session_start_time",
]

df = pd.concat(
    [
        # Get web_mobile
        pd.read_csv(
            os.path.join(
                DATAPATH, "output/realityMine_web_mobile_2022-06-01_2022-06-30.csv"
            ),
            usecols=usecols_web_desktop,
            low_memory=False,
        ),
        # Get web_desktop
        pd.read_csv(
            os.path.join(
                DATAPATH, "output/realityMine_web_desktop_2022-06-01_2022-06-30.csv"
            ),
            usecols=usecols_web_desktop,
            low_memory=False,
        ),
        # Get web
        (
            pd.read_csv(
                os.path.join(
                    DATAPATH, "output/realityMine_web_2022-06-01_2022-06-30.csv"
                ),
                usecols=usecols,
                low_memory=False,
            )
            # Renaming columns to be consistent w/ web_mobile & web_desktop
            .rename_column("session_start_time", "visit_time_local").rename_column(
                "page_duration", "visit_duration"
            )
        ),
    ]
)
print("output = df with web browses")
print(f"{len(df)=:,}")
df.head()
# Out:
# output = df with web browses
# len(df)=6,297,382
#       caseid private_domain                    category     visit_time_local  \
# 0  205323077     google.com  Search Engines and Portals  2022-05-31 23:52:37
# 1  205323077    coupons.com          Business, Shopping  2022-06-01 01:07:35
# 2  205323077     google.com                    Business  2022-06-01 01:15:12
# 3  205323077    coupons.com          Business, Shopping  2022-06-01 01:16:07
# 4  205323077     google.com  Search Engines and Portals  2022-06-01 04:38:10
#
#    visit_duration
# 0               2
# 1             457
# 2              55
# 3            2225
# 4              10

# %% [markdown]
# ## Top gaming and entertainment sites

# %% [markdown]
# ### Duration

# %%
# Top games
(
    df.query("category.str.contains('games', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .rename_column("visit_duration", "duration_games")
    .sort_values("duration_games", ascending=False)
    .head(20)
)
# Out:
#            private_domain                               category  \
# 641             twitch.tv  Entertainment, Games, Streaming Media
# 693       worldwinner.com                                  Games
# 119      chumbacasino.com                        Gambling, Games
# 326    jigsawexplorer.com                                  Games
# 455               pch.com         Business, Entertainment, Games
# 68             bignox.com          Games, Information Technology
# 583        solitaired.com                                  Games
# 602      steampowered.com                        Games, Shopping
# 508     purecasinocash.co                        Gambling, Games
# 116             chess.com                                  Games
# 210          foxwoods.com                        Gambling, Games
# 507             pulsz.com                        Gambling, Games
# 522          rewardia.com                   Entertainment, Games
# 688  worldofsolitaire.com                                  Games
# 468         playcroco.com                        Gambling, Games
# 178         epicgames.com                        Games, Shopping
# 570          slotocash.im                        Gambling, Games
# 374         microsoft.com                        Games, Shopping
# 450    palaceofchance.com                        Gambling, Games
# 620  thejigsawpuzzles.com                                  Games
#
#      duration_games
# 641          497700
# 693          458854
# 119          305032
# 326          266156
# 455          209239
# 68           197308
# 583          178512
# 602          154088
# 508          146392
# 116          143854
# 210          130802
# 507          117980
# 522          111854
# 688           89304
# 468           84534
# 178           82911
# 570           75260
# 374           74243
# 450           71256
# 620           70366

# %%
# Top entertainment
(
    df.query("category.str.contains('entertainment', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .rename_column("visit_duration", "duration_entertainment")
    .sort_values("duration_entertainment", ascending=False)
    .head(20)
)
# Out:
#           private_domain                                   category  \
# 3651         youtube.com             Entertainment, Streaming Media
# 1368          hideout.co  Education, Entertainment, Streaming Media
# 1438            hulu.com             Entertainment, Streaming Media
# 2088         netflix.com             Entertainment, Streaming Media
# 3629           yahoo.com              Entertainment, News and Media
# 1332          hbomax.com                              Entertainment
# 3270           twitch.tv      Entertainment, Games, Streaming Media
# 2490   readmanganato.com                              Entertainment
# 2283       peacocktv.com                              Entertainment
# 2676  showbox-movies.net                              Entertainment
# 1783             loot.tv  Education, Entertainment, Streaming Media
# 3432  washingtonpost.com              Entertainment, News and Media
# 193              aol.com    Business, Entertainment, News and Media
# 1486            imdb.com                              Entertainment
# 3516      windstream.net    Business, Entertainment, News and Media
# 1852       mangaowls.com                              Entertainment
# 2273             pch.com                    Business, Entertainment
# 813       disneyplus.com             Entertainment, Streaming Media
# 2274             pch.com             Business, Entertainment, Games
# 3232          tubitv.com             Entertainment, Streaming Media
#
#       duration_entertainment
# 3651                16018151
# 1368                 5215472
# 1438                 2913677
# 2088                 2351316
# 3629                 1820021
# 1332                  897793
# 3270                  497700
# 2490                  484412
# 2283                  473640
# 2676                  377568
# 1783                  333807
# 3432                  325172
# 193                   318179
# 1486                  290807
# 3516                  274379
# 1852                  249596
# 2273                  246612
# 813                   227618
# 2274                  209239
# 3232                  172988

# %%
# Top shop
(
    df.query("category.str.contains('shop', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .rename_column("visit_duration", "duration_shop")
    .sort_values("duration_shop", ascending=False)
    .head(20)
)
# Out:
#               private_domain                                    category  \
# 154               amazon.com                                    Shopping
# 1153                ebay.com                                    Shopping
# 4082             walmart.com                                    Shopping
# 151               amazon.com                          Business, Shopping
# 1243                etsy.com                                    Shopping
# 632   capitaloneshopping.com                                    Shopping
# 883           craigslist.org          Messageboards and Forums, Shopping
# 2534            mypoints.com                                    Shopping
# 3664              target.com                                    Shopping
# 3030             rakuten.com                          Business, Shopping
# 3547        steampowered.com                             Games, Shopping
# 1804           homedepot.com                                    Shopping
# 4219             xfinity.com                          Business, Shopping
# 4077           walgreens.com                                    Shopping
# 2113              kroger.com                          Business, Shopping
# 940                  cvs.com                                    Shopping
# 2485               mturk.com  Business, Information Technology, Shopping
# 386              bestbuy.com                                    Shopping
# 2292               macys.com                                    Shopping
# 732                chewy.com                          Business, Shopping
#
#       duration_shop
# 154         5044673
# 1153        1199318
# 4082        1166321
# 151          955217
# 1243         426413
# 632          394414
# 883          379426
# 2534         309929
# 3664         275935
# 3030         174099
# 3547         154088
# 1804         152103
# 4219         139210
# 4077         137688
# 2113         120841
# 940          118394
# 2485         115637
# 386          114431
# 2292         114430
# 732          110312

# %% [markdown]
# ### Adult with games, entertainment, shop

# %%
(
    df.query("category.str.contains('entertainment', case=False, na=False)")
    .query("category.str.contains('adult', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .sort_values("visit_duration", ascending=False)
    .head(20)
)
# Out:
#         private_domain                                        category  \
# 110       thechive.com                            Adult, Entertainment
# 101        redgifs.com                            Adult, Entertainment
# 0            4chan.org  Adult, Entertainment, Messageboards and Forums
# 53      hentairead.com                            Adult, Entertainment
# 49       hentaifox.com                            Adult, Entertainment
# 83         nhentai.net                            Adult, Entertainment
# 124         xxxdan.com                            Adult, Entertainment
# 28        e-hentai.org                            Adult, Entertainment
# 55            hpjav.tv                            Adult, Entertainment
# 6           aznude.com                            Adult, Entertainment
# 104    rule34video.com                            Adult, Entertainment
# 108  storiesonline.net                            Adult, Entertainment
# 121        xozilla.com                            Adult, Entertainment
# 80     muchohentai.com                            Adult, Entertainment
# 1           8muses.com                            Adult, Entertainment
# 82      myfreecams.com                            Adult, Entertainment
# 5       ancensored.com                            Adult, Entertainment
# 45         gayforit.eu                            Adult, Entertainment
# 92          porndr.com                            Adult, Entertainment
# 56       hqcollect.net    Adult, Entertainment, Information Technology
#
#      visit_duration
# 110           72879
# 101           26928
# 0             26312
# 53            22878
# 49            17856
# 83            15701
# 124           11854
# 28            10508
# 55             9774
# 6              7124
# 104            6984
# 108            6066
# 121            5082
# 80             4030
# 1              3706
# 82             3598
# 5              2524
# 45             2402
# 92             2380
# 56             2170

# %%
(
    df.query("category.str.contains('games', case=False, na=False)")
    .query("category.str.contains('adult', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .sort_values("visit_duration", ascending=False)
    .head(20)
)
# Out:
#        private_domain                     category  visit_duration
# 2  familysimulator.io                 Adult, Games             519
# 3     freesexgame.com                 Adult, Games             242
# 4          nutaku.net                 Adult, Games             134
# 1        cumshots.com                 Adult, Games              60
# 5   sexyfuckgames.com                 Adult, Games              56
# 0         bigdick.com                 Adult, Games              36
# 6         xvideos.com  Adult, Entertainment, Games               3

# %%
(
    df.query("category.str.contains('shop', case=False, na=False)")
    .query("category.str.contains('adult', case=False, na=False)")
    .groupby(["private_domain", "category"])["visit_duration"]
    .sum()
    .reset_index()
    .sort_values("visit_duration", ascending=False)
    .head(20)
)
# Out:
#          private_domain                        category  visit_duration
# 22         manyvids.com                 Adult, Shopping           18426
# 2           adameve.com                 Adult, Shopping            9434
# 33  victoriassecret.com                 Adult, Shopping            9294
# 12     honeyplaybox.com                 Adult, Shopping            5170
# 28              r18.com       Adult, Business, Shopping            3802
# 19       livejasmin.com                 Adult, Shopping            1434
# 20        lovehoney.com                 Adult, Shopping            1406
# 27  playfulpromises.com                 Adult, Shopping            1272
# 25       pinkcherry.com                 Adult, Shopping             636
# 3    adultdvdempire.com                 Adult, Shopping             498
# 9      edenfantasys.com                 Adult, Shopping             370
# 34            yandy.com                 Adult, Shopping             342
# 8      discountmags.com  Adult, Entertainment, Shopping             316
# 7         crptentry.com                 Adult, Shopping             304
# 30  thecreativefolk.com                 Adult, Shopping             270
# 6          bestvibe.com                 Adult, Shopping             242
# 0           acmejoy.com                 Adult, Shopping             236
# 14         jerkmate.com                 Adult, Shopping             218
# 24   myhornysingles.com                 Adult, Shopping             188
# 10        glamorise.com                 Adult, Shopping             116

# %% [markdown]
# ### Traffic

# %%
# Top games
(
    df.query("category.str.contains('games', case=False, na=False)")
    .groupby(["private_domain", "category"])
    .size()
    .reset_index()
    .rename_column(0, "traffic_games")
    .sort_values("traffic_games", ascending=False)
    .head(20)
)
# Out:
#          private_domain                               category  traffic_games
# 455             pch.com         Business, Entertainment, Games          12074
# 526          roblox.com                                  Games           7219
# 641           twitch.tv  Entertainment, Games, Streaming Media           4971
# 693     worldwinner.com                                  Games           4962
# 602    steampowered.com                        Games, Shopping           3558
# 374       microsoft.com                        Games, Shopping           3316
# 522        rewardia.com                   Entertainment, Games           2823
# 155       dndbeyond.com                   Entertainment, Games           2608
# 178       epicgames.com                        Games, Shopping           2602
# 583      solitaired.com                                  Games           2183
# 116           chess.com                                  Games           2163
# 68           bignox.com          Games, Information Technology           2061
# 119    chumbacasino.com                        Gambling, Games           2059
# 64        betrivers.com              Business, Gambling, Games           2053
# 190          fandom.com        Education, Entertainment, Games           1936
# 723          zleague.gg                Business, Games, Sports           1919
# 599  steamcommunity.com        Games, Messageboards and Forums           1281
# 708        xboxlive.com                                  Games           1266
# 601    steampowered.com                                  Games           1220
# 236       gameduell.com                                  Games           1185

# %%
# Top entertainment
(
    df.query("category.str.contains('entertainment', case=False, na=False)")
    .groupby(["private_domain", "category"])
    .size()
    .reset_index()
    .rename_column(0, "traffic_entertainment")
    .sort_values("traffic_entertainment", ascending=False)
    .head(20)
)
# Out:
#           private_domain                                   category  \
# 3651         youtube.com             Entertainment, Streaming Media
# 3629           yahoo.com              Entertainment, News and Media
# 2274             pch.com             Business, Entertainment, Games
# 1368          hideout.co  Education, Entertainment, Streaming Media
# 1438            hulu.com             Entertainment, Streaming Media
# 2273             pch.com                    Business, Entertainment
# 3630           yahoo.net              Entertainment, News and Media
# 3432  washingtonpost.com              Entertainment, News and Media
# 193              aol.com    Business, Entertainment, News and Media
# 1486            imdb.com                              Entertainment
# 2088         netflix.com             Entertainment, Streaming Media
# 3522   winnerzcircle.com                              Entertainment
# 1241        gocomics.com                              Entertainment
# 38          4channel.org                   Education, Entertainment
# 1293     gunmemorial.org                   Education, Entertainment
# 3219     triviatoday.com                              Entertainment
# 3270           twitch.tv      Entertainment, Games, Streaming Media
# 1462          iheart.com   Business, Entertainment, Streaming Media
# 2173          nypost.com              Entertainment, News and Media
# 2490   readmanganato.com                              Entertainment
#
#       traffic_entertainment
# 3651                 227981
# 3629                  39042
# 2274                  12074
# 1368                  10818
# 1438                  10433
# 2273                   9058
# 3630                   8459
# 3432                   7591
# 193                    7394
# 1486                   7035
# 2088                   6769
# 3522                   5831
# 1241                   5738
# 38                     5714
# 1293                   5200
# 3219                   5088
# 3270                   4971
# 1462                   4834
# 2173                   4336
# 2490                   4300

# %%
# Top shop
(
    df.query("category.str.contains('shop', case=False, na=False)")
    .groupby(["private_domain", "category"])
    .size()
    .reset_index()
    .rename_column(0, "traffic_shop")
    .sort_values("traffic_shop", ascending=False)
    .head(20)
)
# Out:
#               private_domain                                    category  \
# 154               amazon.com                                    Shopping
# 1153                ebay.com                                    Shopping
# 4082             walmart.com                                    Shopping
# 632   capitaloneshopping.com                                    Shopping
# 151               amazon.com                          Business, Shopping
# 2534            mypoints.com                                    Shopping
# 1243                etsy.com                                    Shopping
# 3030             rakuten.com                          Business, Shopping
# 883           craigslist.org          Messageboards and Forums, Shopping
# 3664              target.com                                    Shopping
# 2485               mturk.com  Business, Information Technology, Shopping
# 3547        steampowered.com                             Games, Shopping
# 2404           microsoft.com                             Games, Shopping
# 1935           instacart.com                          Business, Shopping
# 940                  cvs.com                                    Shopping
# 2961   productreportcard.com                          Business, Shopping
# 1804           homedepot.com                                    Shopping
# 2264               lowes.com                                    Shopping
# 4286              zulily.com                                    Shopping
# 386              bestbuy.com                                    Shopping
#
#       traffic_shop
# 154         103487
# 1153         28497
# 4082         26489
# 632          23353
# 151          19333
# 2534         18682
# 1243         13468
# 3030         11505
# 883           7219
# 3664          5702
# 2485          5609
# 3547          3558
# 2404          3316
# 1935          3296
# 940           3247
# 2961          3245
# 1804          2952
# 2264          2923
# 4286          2807
# 386           2783

# %% [markdown]
# ## Prep data

# %%
# Read in list of classified FP (false positives)
falsepositives = (pd
                  .read_csv("../data/false_positives_list.csv")
                  ["flagged as FP"].tolist()
                 )
falsepositives
# Out:
# ['9gag.com',
#  'sniffies.com',
#  'f95zone.to',
#  'silverdaddies.com',
#  'ttcache.com',
#  'xlviirdr.com',
#  '4chan.org',
#  'thechive.com',
#  'victoriassecret.com',
#  'usasexguide.nl',
#  'xlviiirdr.com',
#  'xxxjmp.com',
#  'urbandictionary.com',
#  'lpsg.com']

# %%
# (fold cell) Get data
DATAPATH_IND = "../data/individual_browsing_data.csv"
df_ind = (
    pd.read_csv(DATAPATH_IND)
    # Normalize seconds to hours
    .assign(
        duration_adult=lambda df: df.duration_adult / 3600,
        duration_nonadult=lambda df: df.duration_nonadult / 3600,
    )
    # ==========================================================
    # Get pure adult duration
    .merge(
        (
            df
            .query("category=='Adult'")
            .query("private_domain not in @falsepositives")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_pure_adult")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )
    # ==========================================================
    # Get games sites duration
    .merge(
        (
            df
            .query("category.str.contains('games', case=False, na=False)")
            .query("~category.str.contains('games', case=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_games")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )
    # ==========================================================
    # Get adult games sites duration
    .merge(
        (
            df
            .query("category.str.contains('games', case=False, na=False)")
            .query("category.str.contains('adult', case=False, na=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_adult_games")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )    
    # ==========================================================
    # Get entertainment sites duration
    .merge(
        (
            df
            .query("category.str.contains('entertainment', case=False, na=False)")
            .query("~category.str.contains('adult', case=False, na=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_entertainment")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )
    # ==========================================================
    # Get adult entertainment sites duration
    .merge(
        (
            df
            .query("category.str.contains('entertainment', case=False, na=False)")
            .query("category.str.contains('adult', case=False, na=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_adult_entertainment")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )    
    # ==========================================================
    # Get shopping sites duration
    .merge(
        (
            df
            .query("category.str.contains('shopping', case=False, na=False)")
            .query("~category.str.contains('adult', case=False, na=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_shop")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )
    # ==========================================================
    # Get adult shopping sites duration
    .merge(
        (
            df
            .query("category.str.contains('shopping', case=False, na=False)")
            .query("category.str.contains('adult', case=False, na=False)")
            .groupby("caseid")["visit_duration"]
            .sum()
            .reset_index()
            .rename_column("visit_duration", "duration_adult_shop")
        ),
        how="left",
        on="caseid",
        validate="1:1",
    )
    # ==========================================================
    .assign(
#         # Missing as zeroes
#         **{k: lambda df_, col=k: df_[col].fillna(0) for k in 
#             ["duration_adult_entertainment", "duration_entertainment", "duration_adult_games", 
#              "duration_games", "duration_adult_shop", "duration_shop",]},
        # Compute proportions
        prop_games=lambda df_: 100 * (df_["duration_games"] / df_["duration"]),
        prop_adult_games=lambda df_: 100 * (df_["duration_adult_games"] / df_["duration"]),
        prop_entertainment=lambda df_: 100 * (df_["duration_entertainment"] / df_["duration"]),
        prop_adult_entertainment=lambda df_: 100 * (df_["duration_adult_entertainment"] / df_["duration"]),
        prop_shop=lambda df_: 100 * (df_["duration_shop"] / df_["duration"]),
        prop_adult_shop=lambda df_: 100 * (df_["duration_adult_shop"] / df_["duration"]),
        prop_pure_adult=lambda df_: 100 * (df_["duration_pure_adult"] / df_["duration"]),
    )
    # ==========================================================
    # Normalize duration
    .assign(        
        **{k: lambda df_, col=k: df_[col]/3600 for k in 
            ["duration_adult_entertainment", "duration_entertainment", "duration_adult_games", 
             "duration_games", "duration_adult_shop", "duration_shop", "duration_pure_adult"]},)
)
assert (df_ind["duration_adult"] >= df_ind["duration_pure_adult"]).any()
df_ind
# Out:
#          caseid  birthyr  gender  race  educ  pid3  pid7  presvote20post  \
# 0     200661421     1963       2     1     4     3     3               1
# 1     200686597     1992       2     6     5     5     8              -1
# 2     200953869     1959       2     1     5     2     7               2
# 3     201302005     1966       2     2     3     5     8               1
# 4     201590505     1977       1     4     5     3     3               1
# ...         ...      ...     ...   ...   ...   ...   ...             ...
# 1195    1802885     1935       1     1     6     4     5               2
# 1196    1809723     1943       1     1     2     1     1               1
# 1197    1827351     1947       1     1     5     3     4               1
# 1198    1924249     1980       1     7     4     2     7               2
# 1199    1988109     1953       2     3     5     3     4               6
#
#       inputstate  region party  visits_adult  visits_nonadult   visits  \
# 0             39       2     D           0.0           1728.0   1728.0
# 1             48       3   NaN         243.0           3994.0   4237.0
# 2             42       1     R           0.0             20.0     20.0
# 3             12       3   NaN          20.0            527.0    547.0
# 4              6       4     D           0.0          11086.0  11086.0
# ...          ...     ...   ...           ...              ...      ...
# 1195          12       3     R           NaN              NaN      NaN
# 1196          51       3     D           0.0           9805.0   9805.0
# 1197          31       2     I           0.0            543.0    543.0
# 1198           6       4     R         182.0          21379.0  21561.0
# 1199          51       3     I           0.0           7158.0   7158.0
#
#       prop_adult_visits  rep  duration_adult  duration_nonadult   duration  \
# 0              0.000000  0.0        0.000000          21.567222    77642.0
# 1              5.735190  NaN        7.208889          65.054444   260148.0
# 2              0.000000  1.0        0.000000           0.328333     1182.0
# 3              3.656307  NaN        1.712778           6.626389    30021.0
# 4              0.000000  0.0        0.000000         106.433611   383161.0
# ...                 ...  ...             ...                ...        ...
# 1195                NaN  1.0             NaN                NaN        NaN
# 1196           0.000000  0.0        0.000000         353.503611  1272613.0
# 1197           0.000000  NaN        0.000000           6.646944    23929.0
# 1198           0.844117  1.0        0.581667          86.076667   311970.0
# 1199           0.000000  NaN        0.000000          59.665833   214797.0
#
#       prop_adult_duration  yes_visit_adults  race2  cohort  age  age2  educ2  \
# 0                0.000000               0.0      1    1960   60  3600      4
# 1                9.975860               1.0      5    1990   31   961      4
# 2                0.000000               0.0      1    1960   64  4096      4
# 3               20.538956               1.0      2    1970   57  3249      3
# 4                0.000000               0.0      4    1980   46  2116      4
# ...                   ...               ...    ...     ...  ...   ...    ...
# 1195                  NaN               NaN      1    1940   88  7744      4
# 1196             0.000000               0.0      1    1940   80  6400      2
# 1197             0.000000               0.0      1    1950   76  5776      4
# 1198             0.671218               1.0      5    1980   43  1849      4
# 1199             0.000000               0.0      3    1950   70  4900      4
#
#       duration_pure_adult  duration_games  duration_adult_games  \
# 0                     NaN             NaN                   NaN
# 1                7.207778             NaN                   NaN
# 2                     NaN             NaN                   NaN
# 3                     NaN             NaN                   NaN
# 4                     NaN             NaN                   NaN
# ...                   ...             ...                   ...
# 1195                  NaN             NaN                   NaN
# 1196                  NaN             NaN                   NaN
# 1197                  NaN             NaN                   NaN
# 1198             0.172222             NaN                   NaN
# 1199                  NaN             NaN                   NaN
#
#       duration_entertainment  duration_adult_entertainment  duration_shop  \
# 0                   0.447778                           NaN       9.431667
# 1                   2.401111                           0.0       2.130000
# 2                        NaN                           NaN            NaN
# 3                   0.680833                           NaN       0.471944
# 4                  12.668611                           NaN       3.080556
# ...                      ...                           ...            ...
# 1195                     NaN                           NaN            NaN
# 1196               85.562500                           NaN      33.861111
# 1197                2.779167                           NaN            NaN
# 1198               11.455833                           NaN       3.229444
# 1199                5.440000                           NaN       0.217500
#
#       duration_adult_shop  prop_games  prop_adult_games  prop_entertainment  \
# 0                     NaN         NaN               NaN            2.076196
# 1                     NaN         NaN               NaN            3.322724
# 2                     NaN         NaN               NaN                 NaN
# 3                1.712778         NaN               NaN            8.164285
# 4                     NaN         NaN               NaN           11.902829
# ...                   ...         ...               ...                 ...
# 1195                  NaN         NaN               NaN                 NaN
# 1196                  NaN         NaN               NaN           24.204137
# 1197                  NaN         NaN               NaN           41.811191
# 1198                  NaN         NaN               NaN           13.219540
# 1199                  NaN         NaN               NaN            9.117446
#
#       prop_adult_entertainment  prop_shop  prop_adult_shop  prop_pure_adult
# 0                          NaN  43.731486              NaN              NaN
# 1                          0.0   2.947553              NaN         9.974322
# 2                          NaN        NaN              NaN              NaN
# 3                          NaN   5.659372        20.538956              NaN
# 4                          NaN   2.894345              NaN              NaN
# ...                        ...        ...              ...              ...
# 1195                       NaN        NaN              NaN              NaN
# 1196                       NaN   9.578717              NaN              NaN
# 1197                       NaN        NaN              NaN              NaN
# 1198                       NaN   3.726640              NaN         0.198737
# 1199                       NaN   0.364530              NaN              NaN
#
# [1200 rows x 40 columns]

# %% [markdown]
# ## Lowess

# %%
LOWESS_OPTS = dict(
    frac=0.5,
    it=10,
    delta=0.0,
    return_sorted=True,
)
LINEPLOT_OPTS = dict(c=".3", linewidth=4)
CI_PLOT_OPTS = dict(alpha=0.2, color="b")

# %% [markdown]
# ### Percentage of time

# %%
pairs = [
    # All adult vs non-adult leisure
    ("prop_adult_duration", "prop_entertainment"),
    ("prop_adult_duration", "prop_shop"),
    # Pure adult vs adult-related leisure
    ("prop_pure_adult", "prop_adult_entertainment"),
    ("prop_pure_adult", "prop_adult_shop"),    
    # Pure adult vs nonadult-related leisure
    ("prop_pure_adult", "prop_entertainment"),
    ("prop_pure_adult", "prop_shop"),        
    # Adult-related leisure vs Non-adult-related leisure
    ("prop_entertainment", "prop_adult_entertainment"),
    ("prop_shop", "prop_adult_shop"),
    # Within adult-related leisure
    ("prop_adult_entertainment", "prop_adult_shop"),
    # Within non adult-related leisure
    ("prop_entertainment", "prop_shop"),
]
len(pairs)
# Out:
# 10

# %%
VARLABEL_DICT = dict(
    prop_adult_duration="% online time spent on \nall adult content",
    prop_entertainment="% online time spent on \n non-adult entertainment",
    prop_shop="% online time spent on \n non-adult shopping",
    prop_pure_adult="% online time spent on \npure adult content",
    prop_adult_entertainment="% online time spent on \n adult entertainment",
    prop_adult_shop="% online time spent on \n adult shopping",
    prop_adult_games="% online time spent on \n adult games",
    prop_games="% online time spent on \n non-adult games",
)

# %%
scale = 0.9
for ix, xy in enumerate(pairs):
    xvar, yvar = xy
    print(ix+1, xvar, yvar)
    _df = df_ind.query("duration_adult>0")
    x = _df[xvar].values
    y = _df[yvar].values
    smoothed, eval_x, bottom, top = lowess_ci(x, y, N=1000, lowess_kw=LOWESS_OPTS)
    _, ax = plt.subplots(figsize=(8 * scale, 7 * scale), facecolor="white")
    ax.plot(eval_x, smoothed, **LINEPLOT_OPTS)
    ax.fill_between(eval_x, bottom, top, **CI_PLOT_OPTS)
    ax.set_xlabel(VARLABEL_DICT[xvar], fontsize=22)
    ax.set_ylabel(VARLABEL_DICT[yvar], fontsize=22)
    plt.locator_params(nbins=7) 
    save_mpl_fig(f"../figs/tu_{yvar}-{xvar}")
    plt.show()
# Out:
# 1 prop_adult_duration prop_entertainment
# 2 prop_adult_duration prop_shop
# 3 prop_pure_adult prop_adult_entertainment
# 4 prop_pure_adult prop_adult_shop
# 5 prop_pure_adult prop_entertainment
# 6 prop_pure_adult prop_shop
# 7 prop_entertainment prop_adult_entertainment
# 8 prop_shop prop_adult_shop
# 9 prop_adult_entertainment prop_adult_shop
# 10 prop_entertainment prop_shop

# %% [markdown]
# ### Hours

# %%
pairs = [
    # All adult vs non-adult leisure
    ("duration_adult", "duration_entertainment"),
    ("duration_adult", "duration_shop"),
    # Pure adult vs adult-related leisure
    ("duration_pure_adult", "duration_adult_entertainment"),
    ("duration_pure_adult", "duration_adult_shop"),    
    # Pure adult vs nonadult-related leisure
    ("duration_pure_adult", "duration_entertainment"),
    ("duration_pure_adult", "duration_shop"),        
    # Adult-related leisure vs Non-adult-related leisure
    ("duration_entertainment", "duration_adult_entertainment"),
    ("duration_shop", "duration_adult_shop"),
    # Within adult-related leisure
    ("duration_adult_entertainment", "duration_adult_shop"),
    # Within non adult-related leisure
    ("duration_entertainment", "duration_shop"),
]
len(pairs)
# Out:
# 10

# %%
VARLABEL_DURATION_DICT = dict(
    duration_adult="Hours on all adult content",
    duration_entertainment="Hours on non-adult entertainment",
    duration_shop="Hours on non-adult shopping",
    duration_pure_adult="Hours on pure adult content",
    duration_adult_entertainment="Hours on adult entertainment",
    duration_adult_shop="Hours on adult shopping",
    prop_adult_games="Hours on adult games",
)

# %%
scale = 0.9
for ix, xy in enumerate(pairs):
    xvar, yvar = xy
    print(ix+1, xvar, yvar)
    _df = df_ind.query("duration_adult>0")
    x = _df[xvar].values
    y = _df[yvar].values
    smoothed, eval_x, bottom, top = lowess_ci(x, y, N=1000, lowess_kw=LOWESS_OPTS)
    _, ax = plt.subplots(figsize=(8 * scale, 7 * scale), facecolor="white")
    ax.plot(eval_x, smoothed, **LINEPLOT_OPTS)
    ax.fill_between(eval_x, bottom, top, **CI_PLOT_OPTS)
    ax.set_xlabel(VARLABEL_DURATION_DICT[xvar], fontsize=22)
    ax.set_ylabel(VARLABEL_DURATION_DICT[yvar], fontsize=22)
    plt.locator_params(nbins=7) 
    save_mpl_fig(f"../figs/tu_{yvar}-{xvar}")
    plt.show()
# Out:
# 1 duration_adult duration_entertainment
# 2 duration_adult duration_shop
# 3 duration_pure_adult duration_adult_entertainment
# 4 duration_pure_adult duration_adult_shop
# 5 duration_pure_adult duration_entertainment
# 6 duration_pure_adult duration_shop
# 7 duration_entertainment duration_adult_entertainment
# 8 duration_shop duration_adult_shop
# 9 duration_adult_entertainment duration_adult_shop
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/nonparametric/smoothers_lowess.py:233: RuntimeWarning: invalid value encountered in divide
#   _, weights = _lowess(y, x, x, np.ones_like(x),
# 10 duration_entertainment duration_shop
