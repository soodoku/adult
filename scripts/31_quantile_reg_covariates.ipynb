# %%
import os
import pandas as pd
import janitor
import numpy as np

pd.set_option("display.max_columns", 100)

from utils.data_utils import fit_quantile_reg, esttab_ols_quantile
from utils.utils import save_mpl_fig
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(context="notebook", font_scale=1.05, style="whitegrid", palette="dark")
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

FIGSAVEDIR = "../figs"
DATAPATH = "../data/individual_browsing_data.csv"

df_ind = (
    pd.read_csv(DATAPATH)
    # Normalize seconds to hours
    .assign(
        duration_adult=lambda df: df.duration_adult / 3600,
        duration_nonadult=lambda df: df.duration_nonadult / 3600,
    )
)
df_ind
# Out:
#          caseid  birthyr  gender  race  educ  pid3  pid7  presvote20post  \
# 0     200661421     1963       2     1     4     3     3               1
# 1     200686597     1992       2     6     5     5     8              -1
# 2     200953869     1959       2     1     5     2     7               2
# 3     201302005     1966       2     2     3     5     8               1
# 4     201590505     1977       1     4     5     3     3               1
# ...         ...      ...     ...   ...   ...   ...   ...             ...
# 1195    1802885     1935       1     1     6     4     5               2
# 1196    1809723     1943       1     1     2     1     1               1
# 1197    1827351     1947       1     1     5     3     4               1
# 1198    1924249     1980       1     7     4     2     7               2
# 1199    1988109     1953       2     3     5     3     4               6
#
#       inputstate  region party  visits_adult  visits_nonadult   visits  \
# 0             39       2     D           0.0           1728.0   1728.0
# 1             48       3   NaN         243.0           3994.0   4237.0
# 2             42       1     R           0.0             20.0     20.0
# 3             12       3   NaN          20.0            527.0    547.0
# 4              6       4     D           0.0          11086.0  11086.0
# ...          ...     ...   ...           ...              ...      ...
# 1195          12       3     R           0.0              0.0      0.0
# 1196          51       3     D           0.0           9805.0   9805.0
# 1197          31       2     I           0.0            543.0    543.0
# 1198           6       4     R         182.0          21379.0  21561.0
# 1199          51       3     I           0.0           7158.0   7158.0
#
#       prop_adult_visits  rep  duration_adult  duration_nonadult   duration  \
# 0              0.000000  0.0        0.000000          21.567222    77642.0
# 1              5.735190  NaN        7.208889          65.054444   260148.0
# 2              0.000000  1.0        0.000000           0.328333     1182.0
# 3              3.656307  NaN        1.712778           6.626389    30021.0
# 4              0.000000  0.0        0.000000         106.433611   383161.0
# ...                 ...  ...             ...                ...        ...
# 1195           0.000000  1.0        0.000000           0.000000        0.0
# 1196           0.000000  0.0        0.000000         353.503611  1272613.0
# 1197           0.000000  NaN        0.000000           6.646944    23929.0
# 1198           0.844117  1.0        0.581667          86.076667   311970.0
# 1199           0.000000  NaN        0.000000          59.665833   214797.0
#
#       prop_adult_duration  yes_visit_adults  race2  cohort  age  age2  educ2
# 0                0.000000               0.0      1    1960   60  3600      4
# 1                9.975860               1.0      5    1990   31   961      4
# 2                0.000000               0.0      1    1960   64  4096      4
# 3               20.538956               1.0      2    1970   57  3249      3
# 4                0.000000               0.0      4    1980   46  2116      4
# ...                   ...               ...    ...     ...  ...   ...    ...
# 1195             0.000000               NaN      1    1940   88  7744      4
# 1196             0.000000               0.0      1    1940   80  6400      2
# 1197             0.000000               0.0      1    1950   76  5776      4
# 1198             0.671218               1.0      5    1980   43  1849      4
# 1199             0.000000               0.0      3    1950   70  4900      4
#
# [1200 rows x 26 columns]

# %%
quantiles = np.arange(0.05, 1, 0.05)
quantiles
# Out:
# array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])

# %%
z = "C(gender) + age + age2 + C(race2) + C(educ2) + C(region)"

# %%
# (fold cell) Standard graph opts
opts_connected_line = {
    "linewidth": 2,
    "markersize": 7,
    "markerfacecolor": "0",
    "markeredgecolor": "0",
    "color": ".4",
}
opts_fillbetween = {
    "color": ".7",
    "zorder": 1,
    "alpha": 0.8,
}
opts_0yline = {
    "color": "maroon",
    "alpha": 0.6,
    "linewidth": 2,
    "zorder": 1,
}

# %% [markdown]
# ### Duration on adult

# %%
outcome = "duration_adult"
savepath = "quantile_reg_covariates_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", z=z, quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results,
    columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"],
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(quantile_results[x], quantile_results[y], "o--", **opts_connected_line)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween,
)
plt.axhline(y=0, **opts_0yline)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Hours spent on\nonline pornography", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(
    y=outcome, x="rep", z=z, quantiles=quantiles, df=df_ind
)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: duration_adult</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.17<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.01<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.27)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.03)</td><td>(0.05)</td><td>(0.08)</td><td>(0.13)</td></tr>
# <tr><td style="text-align:left">Female</td><td>-1.52<sup>***</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.04<sup>***</sup></td><td>-0.12<sup>***</sup></td><td>-0.30<sup>***</sup></td><td>-0.66<sup>***</sup></td><td>-1.39<sup>***</sup></td><td>-2.28<sup>***</sup></td><td>-4.07<sup>***</sup></td><td>-9.22<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.35)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.03)</td><td>(0.04)</td><td>(0.07)</td><td>(0.12)</td></tr>
# <tr><td style="text-align:left">Educ (HS)</td><td>0.89<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.03<sup></sup></td><td>0.12<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.31)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.08)</td><td>(0.12)</td><td>(0.19)</td><td>(0.39)</td></tr>
# <tr><td style="text-align:left">Educ (some coll.)</td><td>1.52<sup>**</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.02<sup></sup></td><td>0.13<sup></sup></td><td>0.45<sup>**</sup></td><td>4.44<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.61)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.08)</td><td>(0.12)</td><td>(0.20)</td><td>(0.40)</td></tr>
# <tr><td style="text-align:left">Educ (coll. grad.)</td><td>0.43<sup>**</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.03<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.20)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.08)</td><td>(0.11)</td><td>(0.19)</td><td>(0.39)</td></tr>
# <tr><td style="text-align:left">Age</td><td>0.08<sup>*</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup></sup></td><td>-0.03<sup>**</sup></td><td>-0.01<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.05)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.02)</td></tr>
# <tr><td style="text-align:left">Age$^2$</td><td>-0.00<sup>*</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup>*</sup></td><td>0.00<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td></tr>
# <tr><td style="text-align:left">Race (Black)</td><td>0.60<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.00<sup></sup></td><td>1.67<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.71)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.01)</td><td>(0.03)</td><td>(0.05)</td><td>(0.08)</td><td>(0.13)</td><td>(0.21)</td></tr>
# <tr><td style="text-align:left">Race (Hispanic)</td><td>0.28<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></su

# %% [markdown]
# ### Proportion duration on adult

# %%
outcome = "prop_adult_duration"
savepath = "quantile_reg_covariates_proportion_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", z=z, quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results,
    columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"],
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(quantile_results[x], quantile_results[y], "o--", **opts_connected_line)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween,
)
plt.axhline(y=0, **opts_0yline)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage of time spent on\nonline pornography (%)", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(
    y=outcome, x="rep", z=z, quantiles=quantiles, df=df_ind
)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: prop_adult_duration</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.45<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.00<sup></sup></td><td>0.02<sup></sup></td><td>0.09<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.71)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.03)</td><td>(0.05)</td><td>(0.11)</td><td>(0.18)</td><td>(0.35)</td><td>(0.40)</td></tr>
# <tr><td style="text-align:left">Female</td><td>-4.25<sup>***</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.06<sup>***</sup></td><td>-0.27<sup>***</sup></td><td>-0.86<sup>***</sup></td><td>-1.86<sup>***</sup></td><td>-3.99<sup>***</sup></td><td>-6.83<sup>***</sup></td><td>-13.41<sup>***</sup></td><td>-28.82<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.75)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.05)</td><td>(0.10)</td><td>(0.16)</td><td>(0.33)</td><td>(0.37)</td></tr>
# <tr><td style="text-align:left">Educ (HS)</td><td>3.58<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.05<sup></sup></td><td>0.09<sup></sup></td><td>0.04<sup></sup></td><td>2.60<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.90)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.06)</td><td>(0.12)</td><td>(0.26)</td><td>(0.42)</td><td>(0.86)</td><td>(0.84)</td></tr>
# <tr><td style="text-align:left">Educ (some coll.)</td><td>3.86<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.43<sup></sup></td><td>1.53<sup>***</sup></td><td>3.55<sup>***</sup></td><td>7.48<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.01)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.06)</td><td>(0.12)</td><td>(0.26)</td><td>(0.43)</td><td>(0.87)</td><td>(0.86)</td></tr>
# <tr><td style="text-align:left">Educ (coll. grad.)</td><td>1.27<sup>**</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.29<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.55)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.06)</td><td>(0.12)</td><td>(0.25)</td><td>(0.41)</td><td>(0.84)</td><td>(0.84)</td></tr>
# <tr><td style="text-align:left">Age</td><td>0.18<sup>*</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup></sup></td><td>-0.01<sup></sup></td><td>-0.00<sup></sup></td><td>0.05<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.11)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.03)</td><td>(0.06)</td><td>(0.07)</td></tr>
# <tr><td style="text-align:left">Age$^2$</td><td>-0.00<sup>**</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td></tr>
# <tr><td style="text-align:left">Race (Black)</td><td>2.11<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.91<sup>***</sup></td><td>3.75<sup>***</sup></td><td>11.79<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.55)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.04)</td><td>(0.08)</td><td>(0.17)</td><td>(0.27)</td><td>(0.56)</td><td>(0.65)</td></tr>
# <tr><td style="text-align:left">Race (Hispanic)</td><td>1.33<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup>

# %% [markdown]
# ### Visits to adult

# %%
outcome = "visits_adult"
savepath = "quantile_reg_covariates_visits_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", z=z, quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results,
    columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"],
)

scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(quantile_results[x], quantile_results[y], "o--", **opts_connected_line)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween,
)
plt.axhline(y=0, **opts_0yline)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Visits to pornographic sites", fontsize=15)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Visits to pornographic sites", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))
# Out:
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(
    y=outcome, x="rep", z=z, quantiles=quantiles, df=df_ind
)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# /home/lsys/miniconda3/lib/python3.10/site-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (10000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: visits_adult</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>5.69<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.11<sup></sup></td><td>0.52<sup></sup></td><td>0.10<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(18.77)</td><td>(0.18)</td><td>(0.16)</td><td>(0.15)</td><td>(0.14)</td><td>(0.14)</td><td>(0.14)</td><td>(0.14)</td><td>(0.14)</td><td>(0.14)</td><td>(0.13)</td><td>(0.12)</td><td>(0.18)</td><td>(0.28)</td><td>(0.78)</td><td>(1.29)</td><td>(2.12)</td><td>(2.93)</td><td>(4.86)</td><td>(7.52)</td></tr>
# <tr><td style="text-align:left">Female</td><td>-101.87<sup>***</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-1.00<sup>***</sup></td><td>-5.00<sup>***</sup></td><td>-10.00<sup>***</sup></td><td>-27.00<sup>***</sup></td><td>-48.00<sup>***</sup></td><td>-87.00<sup>***</sup></td><td>-132.44<sup>***</sup></td><td>-268.86<sup>***</sup></td><td>-485.54<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(20.25)</td><td>(0.16)</td><td>(0.14)</td><td>(0.13)</td><td>(0.13)</td><td>(0.13)</td><td>(0.13)</td><td>(0.12)</td><td>(0.12)</td><td>(0.12)</td><td>(0.12)</td><td>(0.11)</td><td>(0.17)</td><td>(0.26)</td><td>(0.72)</td><td>(1.19)</td><td>(1.98)</td><td>(2.69)</td><td>(4.57)</td><td>(6.94)</td></tr>
# <tr><td style="text-align:left">Educ (HS)</td><td>34.86<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.11<sup></sup></td><td>0.56<sup></sup></td><td>0.06<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(25.49)</td><td>(0.40)</td><td>(0.36)</td><td>(0.34)</td><td>(0.33)</td><td>(0.32)</td><td>(0.32)</td><td>(0.32)</td><td>(0.31)</td><td>(0.31)</td><td>(0.30)</td><td>(0.28)</td><td>(0.42)</td><td>(0.64)</td><td>(1.80)</td><td>(3.09)</td><td>(5.28)</td><td>(7.15)</td><td>(11.36)</td><td>(17.80)</td></tr>
# <tr><td style="text-align:left">Educ (some coll.)</td><td>63.67<sup>*</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>1.00<sup></sup></td><td>9.00<sup>*</sup></td><td>9.91<sup></sup></td><td>19.71<sup>*</sup></td><td>109.21<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(36.31)</td><td>(0.41)</td><td>(0.37)</td><td>(0.35)</td><td>(0.34)</td><td>(0.33)</td><td>(0.33)</td><td>(0.32)</td><td>(0.32)</td><td>(0.32)</td><td>(0.31)</td><td>(0.28)</td><td>(0.43)</td><td>(0.65)</td><td>(1.84)</td><td>(3.16)</td><td>(5.35)</td><td>(7.28)</td><td>(11.61)</td><td>(17.98)</td></tr>
# <tr><td style="text-align:left">Educ (coll. grad.)</td><td>16.82<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.05<sup></sup></td><td>0.40<sup></sup></td><td>-0.13<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(22.18)</td><td>(0.39)</td><td>(0.35)</td><td>(0.33)</td><td>(0.32)</td><td>(0.32)</td><td>(0.31)</td><td>(0.31)</td><td>(0.31)</td><td>(0.30)</td><td>(0.29)</td><td>(0.27)</td><td>(0.41)</td><td>(0.63)</td><td>(1.76)</td><td>(3.02)</td><td>(5.15)</td><td>(6.91)</td><td>(10.98)</td><td>(17.53)</td></tr>
# <tr><td style="text-align:left">Age</td><td>0.78<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.27<sup></sup></td><td>-1.34<sup>*</sup></td><td>-2.14<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(2.84)</td><td>(0.03)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.02)</td><td>(0.03)</td><td>(0.04)</td><td>(0.12)</td><td>(0.19)</td><td>(0.33)</td><td>(0.41)</td><td>(0.69)</td><td>(1.06)</td></tr>
# <tr><td style="text-align:left">Age$^2$</td><td>-0.01<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.02<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.03)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.01)</td></tr>
# <tr><td style="text-align:left">Race (Black)</td><td>12.91<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>1.00<sup></sup></td><td>2.00<sup></sup></td><td>2.74<sup></sup></td><td>11.05<sup></sup></td><td>68.00<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(30.38)</td><td>(0.28)</td><td>(0.25)</td><td>(0.23)</td><td>(0.23)</td><td>(0.22)</td><td>(0.22)</td><td>(0.22)</td><td>(0.21)</td><td>(0.21)</td><td>(0.20)</td><td>(0.18)</td><td>(0.28)</td><td>(0.42)</td><td>(1.20)</td><td>(2.01)</td><td>(3.26)</td><td>(4.51)</td><td>(7.74)</td><td>(10.99)</td></tr>
# <tr><td style="text-align:left">Race (Hispanic)</td><td>-15.66<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></su

# %% [markdown]
# ### Proportion visits to adult

# %%
outcome = "prop_adult_visits"
savepath = "quantile_reg_covariates_proportion_visits_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", z=z, quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results,
    columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"],
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(quantile_results[x], quantile_results[y], "o--", **opts_connected_line)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween,
)
plt.axhline(y=0, **opts_0yline)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage of total visits\nto pornographic sites (%)", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(
    y=outcome, x="rep", z=z, quantiles=quantiles, df=df_ind
)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: prop_adult_visits</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.48<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.01<sup></sup></td><td>0.02<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.40)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.08)</td><td>(0.13)</td><td>(0.18)</td><td>(0.24)</td></tr>
# <tr><td style="text-align:left">Female</td><td>-2.87<sup>***</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup>***</sup></td><td>-0.10<sup>***</sup></td><td>-0.33<sup>***</sup></td><td>-0.80<sup>***</sup></td><td>-1.55<sup>***</sup></td><td>-3.27<sup>***</sup></td><td>-6.05<sup>***</sup></td><td>-8.37<sup>***</sup></td><td>-18.46<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.45)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.08)</td><td>(0.12)</td><td>(0.17)</td><td>(0.23)</td></tr>
# <tr><td style="text-align:left">Educ (HS)</td><td>2.20<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.04<sup></sup></td><td>0.08<sup></sup></td><td>0.07<sup></sup></td><td>2.02<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.54)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.02)</td><td>(0.05)</td><td>(0.10)</td><td>(0.19)</td><td>(0.32)</td><td>(0.48)</td><td>(0.62)</td></tr>
# <tr><td style="text-align:left">Educ (some coll.)</td><td>2.23<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.03<sup></sup></td><td>0.07<sup></sup></td><td>0.53<sup>*</sup></td><td>1.22<sup>**</sup></td><td>3.53<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.62)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.02)</td><td>(0.06)</td><td>(0.10)</td><td>(0.19)</td><td>(0.32)</td><td>(0.48)</td><td>(0.64)</td></tr>
# <tr><td style="text-align:left">Educ (coll. grad.)</td><td>0.83<sup>**</sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup></sup></td><td>0.01<sup></sup></td><td>0.01<sup></sup></td><td>0.16<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.33)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.05)</td><td>(0.10)</td><td>(0.18)</td><td>(0.31)</td><td>(0.47)</td><td>(0.62)</td></tr>
# <tr><td style="text-align:left">Age</td><td>0.08<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.02<sup></sup></td><td>-0.02<sup></sup></td><td>-0.03<sup></sup></td><td>-0.03<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.07)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.01)</td><td>(0.02)</td><td>(0.03)</td><td>(0.04)</td></tr>
# <tr><td style="text-align:left">Age$^2$</td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td></tr>
# <tr><td style="text-align:left">Race (Black)</td><td>1.11<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.13<sup>*</sup></td><td>0.17<sup></sup></td><td>0.16<sup></sup></td><td>1.07<sup>***</sup></td><td>3.23<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.94)</td><td>(0.01)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.02)</td><td>(0.04)</td><td>(0.07)</td><td>(0.13)</td><td>(0.20)</td><td>(0.28)</td><td>(0.38)</td></tr>
# <tr><td style="text-align:left">Race (Hispanic)</td><td>0.62<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup><
