# %%
import os
import pandas as pd
import janitor
import numpy as np
pd.set_option('display.max_columns', 100)

from utils.data_utils import fit_quantile_reg, fit_ols_reg,esttab_ols_quantile
from utils.utils import save_mpl_fig
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(context="notebook", font_scale=1.05, style="whitegrid", palette="dark")
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

FIGSAVEDIR = "../figs"
DATAPATH = "../data/individual_browsing_data.csv"        

df_ind = (pd.read_csv(DATAPATH)
          # Normalize seconds to hours
          .assign(
              duration_adult=lambda df: df.duration_adult/3600,
              duration_nonadult=lambda df: df.duration_nonadult/3600,
          )
         )
df_ind
# Out:
#          caseid  birthyr  gender  race  educ  pid3  pid7  presvote20post  \
# 0     200661421     1963       2     1     4     3     3               1
# 1     200686597     1992       2     6     5     5     8              -1
# 2     200953869     1959       2     1     5     2     7               2
# 3     201302005     1966       2     2     3     5     8               1
# 4     201590505     1977       1     4     5     3     3               1
# ...         ...      ...     ...   ...   ...   ...   ...             ...
# 1195    1802885     1935       1     1     6     4     5               2
# 1196    1809723     1943       1     1     2     1     1               1
# 1197    1827351     1947       1     1     5     3     4               1
# 1198    1924249     1980       1     7     4     2     7               2
# 1199    1988109     1953       2     3     5     3     4               6
#
#       inputstate  region party  visits_adult  visits_nonadult   visits  \
# 0             39       2     D           0.0           1580.0   1580.0
# 1             48       3   NaN         243.0           3523.0   3766.0
# 2             42       1     R           0.0             16.0     16.0
# 3             12       3   NaN          20.0            457.0    477.0
# 4              6       4     D           0.0          10755.0  10755.0
# ...          ...     ...   ...           ...              ...      ...
# 1195          12       3     R           NaN              NaN      NaN
# 1196          51       3     D           0.0           9204.0   9204.0
# 1197          31       2     I           0.0            380.0    380.0
# 1198           6       4     R         182.0          19750.0  19932.0
# 1199          51       3     I           0.0           6745.0   6745.0
#
#       prop_adult_visits  rep  duration_adult  duration_nonadult   duration  \
# 0              0.000000  0.0        0.000000          20.198611    72715.0
# 1              6.452469  NaN        7.208889          60.395000   243374.0
# 2              0.000000  1.0        0.000000           0.327778     1180.0
# 3              4.192872  NaN        1.712778           5.775833    26959.0
# 4              0.000000  0.0        0.000000         103.409167   372273.0
# ...                 ...  ...             ...                ...        ...
# 1195                NaN  1.0             NaN                NaN        NaN
# 1196           0.000000  0.0        0.000000         341.600278  1229761.0
# 1197           0.000000  NaN        0.000000           5.134722    18485.0
# 1198           0.913105  1.0        0.581667          80.698611   292609.0
# 1199           0.000000  NaN        0.000000          55.159722   198575.0
#
#       prop_adult_duration  yes_visit_adults  race2  cohort  age  age2  educ2
# 0                0.000000               0.0      1    1960   60  3600      4
# 1               10.663423               1.0      5    1990   31   961      4
# 2                0.000000               0.0      1    1960   64  4096      4
# 3               22.871768               1.0      2    1970   57  3249      3
# 4                0.000000               0.0      4    1980   46  2116      4
# ...                   ...               ...    ...     ...  ...   ...    ...
# 1195                  NaN               NaN      1    1940   88  7744      4
# 1196             0.000000               0.0      1    1940   80  6400      2
# 1197             0.000000               0.0      1    1950   76  5776      4
# 1198             0.715631               1.0      5    1980   43  1849      4
# 1199             0.000000               0.0      3    1950   70  4900      4
#
# [1200 rows x 26 columns]

# %%
quantiles = np.arange(0.05, 1, 0.05)
print(len(quantiles))
quantiles
# Out:
# 19
# array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])

# %%
# (fold cell) Standard graph opts
opts_connected_line = {
    "linewidth":2,
    "markersize":7,
    "markerfacecolor":"0",
    "markeredgecolor":"0",
    "color":".4",
}
opts_fillbetween = {
    "color":".7",
    "zorder":1,
    "alpha":.8,
}
opts_0yline = {
    "color":"maroon",
    "alpha":.6,
    "linewidth":2,
    "zorder":1,
}

# %% [markdown]
# ### Duration on adult

# %%
outcome = "duration_adult"
savepath = "quantile_reg_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)

# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Hours spent on\nonline pornography sites", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: duration_adult</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.28<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup>***</sup></td><td>0.01<sup></sup></td><td>0.17<sup></sup></td><td>0.75<sup>**</sup></td><td>1.61<sup>***</sup></td><td>2.10<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.35)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.04)</td><td>(0.11)</td><td>(0.31)</td><td>(0.49)</td><td>(1.82)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>0.98<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup>***</sup></td><td>0.05<sup>*</sup></td><td>0.16<sup>**</sup></td><td>0.54<sup>***</sup></td><td>1.01<sup>***</sup></td><td>4.52<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.25)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.03)</td><td>(0.07)</td><td>(0.20)</td><td>(0.31)</td><td>(1.15)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>5.19 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.30 (df=831)</td><td>5.29 (df=831)</td><td>5.26 (df=831)</td><td>5.20 (df=831)</td><td>5.26 (df=831)</td><td>6.77 (df=831)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.63<sup></sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ### Proportion duration on adult

# %%
outcome = "prop_adult_duration"
savepath = "quantile_reg_proportion_duration_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage time on pornographic sites", fontsize=15)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage of time spent on\nonline pornography sites (%)", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: prop_adult_duration</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.83<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.01<sup>***</sup></td><td>0.06<sup></sup></td><td>0.21<sup></sup></td><td>2.20<sup></sup></td><td>5.62<sup>*</sup></td><td>18.76<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.85)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.09)</td><td>(0.45)</td><td>(1.43)</td><td>(2.92)</td><td>(5.78)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>3.20<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.01<sup>***</sup></td><td>0.07<sup></sup></td><td>0.83<sup>***</sup></td><td>1.95<sup>**</sup></td><td>5.51<sup>***</sup></td><td>16.81<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.51)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.05)</td><td>(0.28)</td><td>(0.90)</td><td>(1.83)</td><td>(3.63)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td><td>832</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>11.76 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.28 (df=830)</td><td>12.26 (df=830)</td><td>12.05 (df=830)</td><td>11.80 (df=830)</td><td>12.72 (df=830)</td><td>25.45 (df=830)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.95<sup></sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td><td>nan<sup>***</sup> (df=1; 830)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ### Visits to adult

# %%
outcome = "visits_adult"
savepath = "quantile_reg_visits_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)

scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Visits to pornographic sites", fontsize=15)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Traffic to pornography sites", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: visits_adult</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>13.71<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-2.00<sup>***</sup></td><td>2.00<sup></sup></td><td>15.00<sup>*</sup></td><td>53.04<sup>***</sup></td><td>122.00<sup>***</sup></td><td>231.00<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(20.02)</td><td>(0.22)</td><td>(0.20)</td><td>(0.19)</td><td>(0.18)</td><td>(0.18)</td><td>(0.17)</td><td>(0.17)</td><td>(0.17)</td><td>(0.16)</td><td>(0.16)</td><td>(0.15)</td><td>(0.14)</td><td>(0.14)</td><td>(0.26)</td><td>(3.16)</td><td>(7.87)</td><td>(13.77)</td><td>(28.43)</td><td>(94.78)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>59.99<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>2.00<sup>***</sup></td><td>6.00<sup>***</sup></td><td>13.00<sup>***</sup></td><td>28.96<sup>***</sup></td><td>60.00<sup>***</sup></td><td>222.00<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(13.39)</td><td>(0.14)</td><td>(0.12)</td><td>(0.12)</td><td>(0.11)</td><td>(0.11)</td><td>(0.11)</td><td>(0.11)</td><td>(0.11)</td><td>(0.10)</td><td>(0.10)</td><td>(0.10)</td><td>(0.09)</td><td>(0.09)</td><td>(0.17)</td><td>(2.00)</td><td>(4.97)</td><td>(8.71)</td><td>(17.87)</td><td>(60.24)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>288.28 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.71 (df=831)</td><td>295.47 (df=831)</td><td>294.26 (df=831)</td><td>292.01 (df=831)</td><td>289.33 (df=831)</td><td>296.32 (df=831)</td><td>395.66 (df=831)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.47<sup></sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ### Proportion visits to adult

# %%
outcome = "prop_adult_visits"
savepath = "quantile_reg_proportion_visits_adult"

# %%
# (fold cell) plot
quantile_results = [
    fit_quantile_reg(y=outcome, x="rep", quantile=quantile, df=df_ind)
    for quantile in quantiles
]

quantile_results = pd.DataFrame(
    quantile_results, columns=["quantile", "intercept", "estimate", "ll", "hl", "tstat", "pval", "obs"]
)


scale = 0.9
fig, ax = plt.subplots(figsize=(10 * scale, 8 * scale), facecolor="white")

y = "estimate"
x = "quantile"
plt.plot(
    quantile_results[x],
    quantile_results[y],
    "o--",
    **opts_connected_line
)
plt.fill_between(
    quantile_results[x],
    quantile_results["ll"],
    quantile_results["hl"],
    **opts_fillbetween
)
plt.axhline(y=0, **opts_0yline)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage visits to pornographic sites", fontsize=15)
# Custom Legend
quantile_estimates = mlines.Line2D(
    [],
    [],
    marker="o",
    ls="--",
    **opts_connected_line,
    label="Quantile estimates (connected)",
)
ci = mpatches.Patch(**opts_fillbetween, label="95% confidence interval")
custom_legend = plt.legend(
    handles=[quantile_estimates, ci],
    handlelength=4,
    handletextpad=0.3,
    labelspacing=0.3,
    frameon=False,
    prop={"weight": "bold", "size": 14},
    loc="best",
    #     title_fontproperties={'weight':'bold', 'size':14},
)
ax.set_xlabel("Quantile", fontsize=15)
ax.set_ylabel("Percentage of traffic to pornography sites (%)", fontsize=15)
save_mpl_fig(os.path.join(FIGSAVEDIR, savepath))

# %%
# Get tables
regtab_frag, regtab = esttab_ols_quantile(y=outcome, x="rep", quantiles=quantiles, df=df_ind)
with open(f"../tabs/regtab_{savepath}.tex", "w") as tf:
    tf.write(regtab_frag)

regtab
# Out:
# <table style="text-align:center"><tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="20"><em>Dependent variable: prop_adult_visits</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td><td>(9)</td><td>(10)</td><td>(11)</td><td>(12)</td><td>(13)</td><td>(14)</td><td>(15)</td><td>(16)</td><td>(17)</td><td>(18)</td><td>(19)</td><td>(20)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Republican</td><td>0.67<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.00<sup></sup></td><td>-0.04<sup>***</sup></td><td>0.10<sup></sup></td><td>0.69<sup>**</sup></td><td>1.70<sup>**</sup></td><td>2.50<sup>*</sup></td><td>9.88<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.55)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.01)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.01)</td><td>(0.16)</td><td>(0.34)</td><td>(0.76)</td><td>(1.46)</td><td>(2.89)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>1.96<sup>***</sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.00<sup></sup></td><td>0.04<sup>***</sup></td><td>0.17<sup>*</sup></td><td>0.46<sup>**</sup></td><td>1.41<sup>***</sup></td><td>5.34<sup>***</sup></td><td>10.07<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.31)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.00)</td><td>(0.10)</td><td>(0.22)</td><td>(0.48)</td><td>(0.92)</td><td>(1.82)</td></tr>
#
# <td colspan="21" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td><td>833</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.00</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>7.47 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.81 (df=831)</td><td>7.80 (df=831)</td><td>7.75 (df=831)</td><td>7.62 (df=831)</td><td>7.49 (df=831)</td><td>8.58 (df=831)</td><td>14.68 (df=831)</td></tr><tr><td style="text-align: left">F Statistic</td><td>1.49<sup></sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td><td>nan<sup>***</sup> (df=1; 831)</td></tr>
# <tr><td colspan="21" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="20" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
