# %%
import os
import pandas as pd
import janitor
import numpy as np
pd.set_option('display.max_columns', 100)

DATAPATH = "../../adult-data"

# %%
# (fold cell) Load and prep web browsing data
# output = df with visits to adult sites
usecols_web_desktop = ["caseid", "category", "private_domain", "visit_duration", "visit_time_local"]
usecols = ["caseid", "category", "private_domain", "page_duration", "session_start_time"]

df = (pd.concat([
        # Get web_mobile
        pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_mobile_2022-06-01_2022-06-30.csv"),
            usecols=usecols_web_desktop,
            low_memory=False,
        ), 
        # Get web_desktop
        pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_desktop_2022-06-01_2022-06-30.csv"),
            usecols=usecols_web_desktop,
            low_memory=False,
        ),
        # Get web
        (pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_2022-06-01_2022-06-30.csv"),
            usecols=usecols,
            low_memory=False,
        )
         # Renaming columns to be consistent w/ web_mobile & web_desktop
         .rename_column("session_start_time", "visit_time_local")
         .rename_column("page_duration", "visit_duration")
        )
    ])
     )
print("output = df with web browses")
print(f"{len(df)=:,}")
df.head()
# Out:
# output = df with web browses
# len(df)=6,297,382
#       caseid private_domain                    category     visit_time_local  \
# 0  205323077     google.com  Search Engines and Portals  2022-05-31 23:52:37
# 1  205323077    coupons.com          Business, Shopping  2022-06-01 01:07:35
# 2  205323077     google.com                    Business  2022-06-01 01:15:12
# 3  205323077    coupons.com          Business, Shopping  2022-06-01 01:16:07
# 4  205323077     google.com  Search Engines and Portals  2022-06-01 04:38:10
#
#    visit_duration
# 0               2
# 1             457
# 2              55
# 3            2225
# 4              10

# %%
# (fold cell) list of unique domains
df_domains = (df
              # this gives repeated domains (e.g. google.com 
             # is both "Search Engines and Portals" and "Chat and Instant Messaging" )
#               .groupby(["private_domain", "category"])  
              .groupby(["private_domain"])
              .size()
              .reset_index()
              .rename_column(0, "tt_visits")
              .sort_values("tt_visits", ascending=False, ignore_index=True)
             )
print(len(df_domains))
df_domains.to_csv("unique_domains.csv", index=False)
df_domains.head(50)
# Out:
# 64074
#                private_domain  tt_visits
# 0                  google.com     986722
# 1                facebook.com     449173
# 2                   yahoo.com     245982
# 3                    bing.com     235769
# 4                 youtube.com     232829
# 5                  amazon.com     126255
# 6                 twitter.com     111465
# 7             decipherinc.com      84099
# 8                    live.com      79960
# 9                  reddit.com      61109
# 10              instagram.com      48674
# 11                    aol.com      47281
# 12                    msn.com      39157
# 13                 clarity.ms      34935
# 14        microsoftonline.com      34600
# 15                 yougov.com      32935
# 16                   ebay.com      30478
# 17                 paypal.com      27712
# 18                walmart.com      27437
# 19              wikipedia.org      27017
# 20               samplicio.us      26155
# 21             privatelink.de      26006
# 22              microsoft.com      25826
# 23                  sentry.io      24969
# 24                    pch.com      24231
# 25     capitaloneshopping.com      23356
# 26                discord.com      23271
# 27                 dynata.com      22128
# 28               linkedin.com      19346
# 29                 zillow.com      19005
# 30               mypoints.com      18857
# 31               google.co.uk      18307
# 32                 office.com      17684
# 33               fbcdnx14.net      16771
# 34             msftstatic.com      16528
# 35           inboxdollars.com      16089
# 36                   zoho.com      15246
# 37                  chase.com      13809
# 38  democraticunderground.com      13663
# 39                   etsy.com      13485
# 40                 indeed.com      11908
# 41                rakuten.com      11539
# 42           surveyjunkie.com      11471
# 43                   hulu.com      10893
# 44                 hideout.co      10824
# 45                  quora.com      10575
# 46              ebesucher.com      10475
# 47                smugmug.com      10315
# 48                xfinity.com      10064
# 49                 tiktok.com       9980
