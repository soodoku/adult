# %%
import os
import pandas as pd
import janitor
import numpy as np
pd.set_option('display.max_columns', 100)

DATAPATH = "../../adult-data"

# %%
# (fold cell) Load and prep web browsing data
# output = df with visits to adult sites
usecols_web_desktop = ["caseid", "category", "private_domain", "visit_duration", "visit_time_local"]
usecols = ["caseid", "category", "private_domain", "page_duration", "session_start_time"]

df = (pd.concat([
        # Get web_mobile
        pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_mobile_2022-06-01_2022-06-30.csv"),
            usecols=usecols_web_desktop,
            low_memory=False,
        ), 
        # Get web_desktop
        pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_desktop_2022-06-01_2022-06-30.csv"),
            usecols=usecols_web_desktop,
            low_memory=False,
        ),
        # Get web
        (pd.read_csv(
            os.path.join(DATAPATH, "output/realityMine_web_2022-06-01_2022-06-30.csv"),
            usecols=usecols,
            low_memory=False,
        )
         # Renaming columns to be consistent w/ web_mobile & web_desktop
         .rename_column("session_start_time", "visit_time_local")
         .rename_column("page_duration", "visit_duration")
        )
    ])
     )
print("output = df with web browses")
print(f"{len(df)=:,}")
df.head()
# Out:
# output = df with web browses
# len(df)=5,090,441
#       caseid     private_domain                   category  \
# 0  210362181  liveineverett.com                        NaN
# 1  210362181             wa.gov      Education, Government
# 2  210362181          yahoo.com        Economy and Finance
# 3  210362181       collider.com              Entertainment
# 4  210362181          yahoo.com  Education, News and Media
#
#       visit_time_local  visit_duration
# 0  2022-05-31 17:19:01              50
# 1  2022-05-31 19:28:41              48
# 2  2022-06-01 03:16:33               1
# 3  2022-06-01 03:29:15              60
# 4  2022-06-01 03:42:43              83

# %%
# (fold cell) list of unique domains
df_domains = (df
              .groupby(["private_domain", "category"])
              .size()
              .reset_index()
              .rename_column(0, "tt_visits")
              .sort_values("tt_visits", ascending=False, ignore_index=True)
             )
print(len(df_domains))
df_domains.to_csv("unique_domains.csv", index=False)
df_domains.head(50)
# Out:
# 27038
#             private_domain                                           category  \
# 0               google.com                         Search Engines and Portals
# 1             facebook.com                        Business, Social Networking
# 2               google.com                         Chat and Instant Messaging
# 3                 bing.com         News and Media, Search Engines and Portals
# 4              youtube.com                     Entertainment, Streaming Media
# 5                yahoo.com                         Chat and Instant Messaging
# 6               amazon.com                                           Shopping
# 7          decipherinc.com                                           Business
# 8              twitter.com                                  Social Networking
# 9                 live.com                         Chat and Instant Messaging
# 10              reddit.com           Messageboards and Forums, News and Media
# 11                 msn.com                    News and Media, Streaming Media
# 12                 aol.com                         Chat and Instant Messaging
# 13     microsoftonline.com                             Information Technology
# 14               yahoo.com                      Entertainment, News and Media
# 15              google.com                                  Translation Sites
# 16          privatelink.de                                           Business
# 17              clarity.ms                   Business, Information Technology
# 18               sentry.io                   Business, Information Technology
# 19             walmart.com                                           Shopping
# 20  capitaloneshopping.com                                           Shopping
# 21           instagram.com                   Media Sharing, Social Networking
# 22           wikipedia.org                                          Education
# 23              dynata.com                                           Business
# 24            samplicio.us                                           Business
# 25            mypoints.com                                           Shopping
# 26              yougov.com                                Business, Education
# 27              paypal.com                      Business, Economy and Finance
# 28            google.co.uk                         Search Engines and Portals
# 29                ebay.com                                           Shopping
# 30              office.com                         Chat and Instant Messaging
# 31                 pch.com                     Business, Entertainment, Games
# 32             discord.com                         Chat and Instant Messaging
# 33        inboxdollars.com                   Business, Information Technology
# 34               yahoo.com                         Search Engines and Portals
# 35           microsoft.com                             Information Technology
# 36             rakuten.com                                 Business, Shopping
# 37               chase.com                      Business, Economy and Finance
# 38             xfinity.com                                           Business
# 39           ebesucher.com                                           Business
# 40              amazon.com                                 Business, Shopping
# 41          duckduckgo.com  Business, Information Technology, Search Engin...
# 42             smugmug.com                                           Business
# 43                 pch.com                            Business, Entertainment
# 44     researchresults.com                                           Business
# 45              tiktok.com                   Media Sharing, Social Networking
# 46          trendmicro.com                                           Business
# 47               yahoo.com                                Economy and Finance
# 48           nielseniq.com                                           Business
# 49            linkedin.com                     Job Related, Social Networking
#
#     tt_visits
# 0      533733
# 1      395034
# 2      231056
# 3      203672
# 4      152849
# 5      149049
# 6       79514
# 7       75200
# 8       68639
# 9       60410
# 10      41389
# 11      38901
# 12      30843
# 13      30812
# 14      29839
# 15      26488
# 16      26006
# 17      23834
# 18      22088
# 19      20547
# 20      20233
# 21      19496
# 22      19262
# 23      19127
# 24      18679
# 25      17731
# 26      17346
# 27      16902
# 28      16222
# 29      15029
# 30      14166
# 31      14150
# 32      13265
# 33      12623
# 34      12484
# 35      12394
# 36      11413
# 37      11054
# 38      10591
# 39      10475
# 40      10467
# 41      10312
# 42      10305
# 43       9861
# 44       9767
# 45       9537
# 46       9376
# 47       9300
# 48       9094
# 49       8983
